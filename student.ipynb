# %% [markdown]
# ## Final Project Submission
#
#
# * Student name: Joe Garcia
# * Student pace: full time
# * Scheduled project review date/time: 3/11/2022, 11am
# * Instructor name: Praveen Gowtham
# * Blog post URL:

# %%
# Your code here - remember to use markdown cells for comments as well!

import pandas as pd
import math

# %%
#Here I unzipped the movie_basics.csv, and created a Pandas dataframe (df1)

df1 = pd.read_csv('zippedData/movie_basics_extracted.csv', index_col=False)
df1
# Out:
#         Unnamed: 0   movie_id                                primary_title  \
# 0                0  tt0063540                                    Sunghursh
# 1                1  tt0066787              One Day Before the Rainy Season
# 2                2  tt0069049                   The Other Side of the Wind
# 3                3  tt0069204                              Sabse Bada Sukh
# 4                4  tt0100275                     The Wandering Soap Opera
# ...            ...        ...                                          ...
# 146139      146139  tt9916538                          Kuambil Lagi Hatiku
# 146140      146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141      146141  tt9916706                              Dankyavar Danka
# 146142      146142  tt9916730                                       6 Gunn
# 146143      146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# ...

# %%
#Here I unzipped the the movie_ratings.csv and created a Pandas dataframe (df2)
df2 = pd.read_csv('zippedData/movie_ratings_extracted.csv')
df2
# Out:
#        Unnamed: 0    movie_id  averagerating  numvotes
# 0               0  tt10356526            8.3        31
# 1               1  tt10384606            8.9       559
# 2               2   tt1042974            6.4        20
# 3               3   tt1043726            4.2     50352
# 4               4   tt1060240            6.5        21
# ...           ...         ...            ...       ...
# 73851       73851   tt9805820            8.1        25
# 73852       73852   tt9844256            7.5        24
# 73853       73853   tt9851050            4.7        14
# 73854       73854   tt9886934            7.0         5
# 73855       73855   tt9894098            6.3       128
#
# [73856 rows x 4 columns]

# %%
#Here I unzipped the bom.movie_gross.csv and created a Pandas dataframe (df3)
df3 = pd.read_csv('zippedData/bom.movie_gross.csv')
df3
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#looking for NaNs inside df3


df3_nan = df3[df3['foreign_gross'].isna()]
df3_nan
# Out:
#                                        title      studio  domestic_gross  \
# 222                                  Flipped          WB       1800000.0
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# 269            Grease (Sing-a-Long re-issue)        Par.        366000.0
# 280                          Last Train Home       Zeit.        288000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 222            NaN  2010
# 254            NaN  2010
# ...

# %%
#who is the competition
df3['studio']
# Out:
# 0               BV
# 1               BV
# 2               WB
# 3               WB
# 4             P/DW
#            ...
# 3382         Magn.
# 3383            FM
# 3384          Sony
# 3385    Synergetic
# 3386         Grav.
# Name: studio, Length: 3387, dtype: object

# %%
df3['domestic_gross']
# Out:
# 0       415000000.0
# 1       334200000.0
# 2       296000000.0
# 3       292600000.0
# 4       238700000.0
#            ...
# 3382         6200.0
# 3383         4800.0
# 3384         2500.0
# 3385         2400.0
# 3386         1700.0
# Name: domestic_gross, Length: 3387, dtype: float64

# %%
df4 = pd.read_csv('zippedData/tn.movie_budgets.csv')
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
worldwide_prod_list = list(df4['worldwide_gross']/df4['production_budget'])
len(worldwide_prod_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# ...

# %%
worldwode_prod_rounded = [round(worldwide_prod_list[x] , 2) for x in list(range(0,len(worldwide_prod_list)))]

sorted(worldwode_prod_rounded, reverse = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-57028a742598> in <module>
# ----> 1 worldwode_prod_rounded = [round(worldwide_prod_list[x] , 2) for x in list(range(0,len(worldwide_prod_list)))]
#       2
#       3 sorted(worldwode_prod_rounded, reverse = True)
#
# NameError: name 'worldwide_prod_list' is not defined

# %%
df4['ROI for WorldWide'] = worldwode_prod_rounded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-6ad2fe85166d> in <module>
# ----> 1 df4['ROI for WorldWide'] = worldwode_prod_rounded
#
# NameError: name 'worldwode_prod_rounded' is not defined

# %%
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
#so trying to display worldwide_ROI 

df4.sort_values( by= "ROI for WorldWide", ascending = False).head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-b9aed9e8717c> in <module>
#       1 #so trying to display worldwide_ROI
#       2
# ----> 3 df4.sort_values( by= "ROI for WorldWide", ascending = False).head(50)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5292
#    5293             by = by[0]
# -> 5294             k = self._get_label_or_level_values(by, axis=axis)
#    5295
#    5296             # need to rewrap column in Series to apply key function
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
# ...

# %%
dom_prod_list = list(df4['domestic_gross']/df4['production_budget'])
len(dom_prod_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/computation/expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/computation/expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# ...

# %%
dom_prod_list_rounded = [round(dom_prod_list[x] , 2) for x in list(range(0,len(dom_prod_list)))]

sorted_rounded_list = sorted(dom_prod_list_rounded[0:10], reverse = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-2588aa9a40ab> in <module>
# ----> 1 dom_prod_list_rounded = [round(dom_prod_list[x] , 2) for x in list(range(0,len(dom_prod_list)))]
#       2
#       3 sorted_rounded_list = sorted(dom_prod_list_rounded[0:10], reverse = True)
#
# NameError: name 'dom_prod_list' is not defined

# %%
movie_names_list = list(sorted(df4['movie'].head(10)))

# %%
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline


bar_chart_title = 'ROI form Domestic Revenue' 
bar_chart_count_label = ' ROI'
bar_chart_series_label = 'Movie Names'


player_count_figure2, ax = plt.subplots(figsize=(16, 13))

ax.bar(x = movie_names_list , height = sorted_rounded_list) 

ax.set_title(bar_chart_title) 
ax.set_xlabel(bar_chart_series_label) 
ax.set_ylabel(bar_chart_count_label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-74164eaef324> in <module>
#      11 player_count_figure2, ax = plt.subplots(figsize=(16, 13))
#      12
# ---> 13 ax.bar(x = movie_names_list , height = sorted_rounded_list)
#      14
#      15 ax.set_title(bar_chart_title)
#
# NameError: name 'sorted_rounded_list' is not defined

# %%
df4.drop(labels=, axis="columns", inplace=True)
# Out:
#   File "<ipython-input-40-d08be462d1da>", line 1
#     df4.drop(labels=, axis="columns", inplace=True)
#                     ^
# SyntaxError: invalid syntax

# %%
df4['ROI for Domestic'] = dom_prod_list_rounded
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-faa9ac949e3f> in <module>
# ----> 1 df4['ROI for Domestic'] = dom_prod_list_rounded
#
# NameError: name 'dom_prod_list_rounded' is not defined

# %%
df4.sort_values( by= "ROI for Domestic", ascending = False).head(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-65dbb019a28c> in <module>
# ----> 1 df4.sort_values( by= "ROI for Domestic", ascending = False).head(50)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5292
#    5293             by = by[0]
# -> 5294             k = self._get_label_or_level_values(by, axis=axis)
#    5295
#    5296             # need to rewrap column in Series to apply key function
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# ...

# %%
df4[['movie', 'ROI for Domestic']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-096c40aac85a> in <module>
# ----> 1 df4[['movie', 'ROI for Domestic']]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
df5 = pd.read_csv('zippedData/tmdb.movies.csv')
df5
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 7 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       146144 non-null  int64
#  1   movie_id         146144 non-null  object
#  2   primary_title    146144 non-null  object
#  3   original_title   146123 non-null  object
#  4   start_year       146144 non-null  int64
#  5   runtime_minutes  114405 non-null  float64
#  6   genres           140736 non-null  object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 7.8+ MB
# None

# %%
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     73856 non-null  int64
#  1   movie_id       73856 non-null  object
#  2   averagerating  73856 non-null  float64
#  3   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 2.3+ MB
# None

# %%
df1['movie_id']
# Out:
# 0         tt0063540
# 1         tt0066787
# 2         tt0069049
# 3         tt0069204
# 4         tt0100275
#             ...
# 146139    tt9916538
# 146140    tt9916622
# 146141    tt9916706
# 146142    tt9916730
# 146143    tt9916754
# Name: movie_id, Length: 146144, dtype: object

# %%
df2['movie_id']
# Out:
# 0        tt10356526
# 1        tt10384606
# 2         tt1042974
# 3         tt1043726
# 4         tt1060240
#             ...
# 73851     tt9805820
# 73852     tt9844256
# 73853     tt9851050
# 73854     tt9886934
# 73855     tt9894098
# Name: movie_id, Length: 73856, dtype: object

# %%
to_concat_ratings = [df1, df2]

# %%
ratings_df = pd.concat(to_concat_ratings)

# %%
ratings_df.sort_values(by=['movie_id']).head(50)
# Out:
#        Unnamed: 0   movie_id  \
# 0               0  tt0063540
# 36049       36049  tt0063540
# 1               1  tt0066787
# 725           725  tt0066787
# 2               2  tt0069049
# 18429       18429  tt0069049
# 2223         2223  tt0069204
# 3               3  tt0069204
# 1143         1143  tt0100275
# 4               4  tt0100275
# 5               5  tt0111414
# 6               6  tt0112502
# 55676       55676  tt0112502
# 7               7  tt0137204
# 30166       30166  tt0137204
# 8               8  tt0139613
# 9               9  tt0144449
# 10             10  tt0146592
# 55677       55677  tt0146592
# 11             11  tt0154039
# 28904       28904  tt0154039
# 12             12  tt0159369
# 68822       68822  tt0159369
# 13             13  tt0162942
# 59244       59244  tt0162942
# 68823       68823  tt0170651
# 14             14  tt0170651
# 15             15  tt0176694
# 62126       62126  tt0176694
# 16             16  tt0187902
# 17             17  tt0192528
# ...

# %%
to_concat_budget = [df4, df3]

# %%
overall_budget = pd.concat(to_concat_budget)

# %%
df.sort_values(by=['col1'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-eb3675e6c825> in <module>
# ----> 1 df.sort_values(by=['col1'])
#
# NameError: name 'df' is not defined

# %%
from re import sub
from decimal import Decimal

# changes money string to a float 
def change_money_to_float(money_string):
    float_value= float(Decimal(sub(r'[^\d.]', '', money_string)) )
    return float_value

# %%
domestic_gross_list =list(df4['domestic_gross'][0:])

domestic_gross_df4 = [ change_money_to_float(t) for t in domestic_gross_list] 

# Dropping old domestic_gross column and putting the new one in that has floats

columns_to_overwrite1 = ['domestic_gross']

df4.drop(labels=columns_to_overwrite1, axis="columns", inplace=True)

df4['domestic_gross'] = domestic_gross_df4

# %%
worldwide_list =list(df4['worldwide_gross'][0:])

worldwide_gross_df4 = [ change_money_to_float(t) for t in worldwide_list]

# Doing the same to worldwide_gross

columns_to_overwrite2 = ['worldwide_gross']

df4.drop(labels=columns_to_overwrite2, axis="columns", inplace=True)

df4['worldwide_gross'] = worldwide_gross_df4

# %%
production_budget_list =list(df4['production_budget'][0:])

production_budget_df4 = [ change_money_to_float(t) for t in production_budget_list]

# Doing the same to production_budget

columns_to_overwrite3 = ['production_budget']

df4.drop(labels=columns_to_overwrite3, axis="columns", inplace=True)

df4['production_budget'] = production_budget_df4

# %%
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       domestic_gross  worldwide_gross  production_budget
# 0        760507625.0     2.776345e+09        425000000.0
# ...

# %%
df4['production_budget']/df4['domestic_gross']
# Out:
# 0       0.558837
# 1       1.703283
# 2       8.184770
# 3       0.720252
# 4       0.511141
#           ...
# 5777         inf
# 5778    0.123757
# 5779    3.736921
# 5780         inf
# 5781    0.006076
# Length: 5782, dtype: float64

# %%
original_df[columns_to_overwrite] = other_data_frame[columns_to_overwrite]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-0f00fa38daee> in <module>
# ----> 1 original_df[columns_to_overwrite] = other_data_frame[columns_to_overwrite]
#
# NameError: name 'other_data_frame' is not defined

# %%
to_concat_budget = [df4, df3]

# %%
overall_budget = pd.concat(to_concat_budget)

# %%
overall_budget['domestic_gross']
# Out:
# 0       760507625.0
# 1       241063875.0
# 2        42762350.0
# 3       459005868.0
# 4       620181382.0
#            ...
# 3382         6200.0
# 3383         4800.0
# 3384         2500.0
# 3385         2400.0
# 3386         1700.0
# Name: domestic_gross, Length: 9169, dtype: float64

# %%
df4["domestic_gross"][3]
# Out:
# 459005868.0

# %%
test_in_floats=[]
for t in test:
    test_in_floats.append(change_money_to_float(t))
    
test_in_floats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-49e9e72f0c80> in <module>
#       1 test_in_floats=[]
# ----> 2 for t in test:
#       3     test_in_floats.append(change_money_to_float(t))
#       4
#       5 test_in_floats
#
# NameError: name 'test' is not defined

# %%
import matplotlib
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
bar_chart_title = 'XXXXXX' 
bar_chart_count_label = 'XXXX'
bar_chart_series_label = 'XXX'

# %%
player_count_figure, ax = plt.subplots(figsize=(10, 6))

ax.plot.line(x = XXXXX, height = XXXXXXX) 

ax.set_title(bar_chart_title) 
ax.set_xlabel(bar_chart_series_label) 
ax.set_ylabel(bar_chart_count_label)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-4c045eb2471c> in <module>
#       1 player_count_figure, ax = plt.subplots(figsize=(10, 6))
#       2
# ----> 3 ax.plot.line(x = XXXXX, height = XXXXXXX)
#       4
#       5 ax.set_title(bar_chart_title)
#
# AttributeError: 'function' object has no attribute 'line'

# %%
overall_budget[['movie', 'title']]
# Out:
#                                             movie                        title
# 0                                          Avatar                          NaN
# 1     Pirates of the Caribbean: On Stranger Tides                          NaN
# 2                                    Dark Phoenix                          NaN
# 3                         Avengers: Age of Ultron                          NaN
# 4               Star Wars Ep. VIII: The Last Jedi                          NaN
# ...                                           ...                          ...
# 3382                                          NaN                    The Quake
# 3383                                          NaN  Edward II (2018 re-release)
# 3384                                          NaN                     El Pacto
# 3385                                          NaN                     The Swan
# 3386                                          NaN            An Actor Prepares
#
# [9169 rows x 2 columns]

# %%
df1['start_year'].sort_values
# Out:
# <bound method Series.sort_values of 0         2013
# 1         2019
# 2         2018
# 3         2018
# 4         2017
#           ...
# 146139    2019
# 146140    2015
# 146141    2013
# 146142    2017
# 146143    2013
# Name: start_year, Length: 146144, dtype: int64>

# %%
how_many_appearances_by_countries = (df.groupby('Nationality')['Name'].count())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-6aa666dba84f> in <module>
# ----> 1 how_many_appearances_by_countries = (df.groupby('Nationality')['Name'].count())
#
# NameError: name 'df' is not defined

# %%
list(df1['genres'])
# Out:
# ['Action,Crime,Drama',
#  'Biography,Drama',
#  'Drama',
#  'Comedy,Drama',
#  'Comedy,Drama,Fantasy',
#  'Comedy',
#  'Horror,Thriller',
#  'Adventure,Animation,Comedy',
#  'Documentary,History',
#  'Biography',
#  'Drama',
#  'History',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Animation,Drama,History',
#  nan,
#  'Drama',
#  'Drama',
#  'Drama,Mystery',
#  'Action,Animation,Comedy',
#  'Crime,Drama',
#  nan,
#  'Biography,Comedy,Drama',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Action,Drama',
#  'Documentary,History',
#  'Sci-Fi',
#  'Comedy',
#  'Documentary',
#  'Thriller',
#  'Action,Adventure,Fantasy',
#  'Crime,Drama',
#  nan,
#  'Drama,Romance',
#  'Adventure,Animation,Sci-Fi',
#  'Action,Crime,Drama',
#  'Drama,Horror',
#  nan,
#  'Drama,Mystery,Thriller',
#  'Drama,Family',
#  'Adventure,Comedy,Romance',
#  nan,
#  nan,
#  'Comedy,Drama',
#  'Adventure,Animation,Comedy',
#  'Adventure,Drama,Romance',
#  'Comedy,Crime,Drama',
#  'Biography',
# ...

# %%
#get the counts of the animation the actual number by genre
df1_genres = (df1.groupby('genres')['movie_id'].count())
df1_genres
# Out:
# genres
# Action                        2219
# Action,Adult,Comedy              2
# Action,Adventure               114
# Action,Adventure,Animation     197
# Action,Adventure,Biography      34
#                               ...
# Thriller,War,Western             1
# Thriller,Western                 4
# War                            131
# War,Western                      1
# Western                        142
# Name: movie_id, Length: 1085, dtype: int64

# %%
sorted_genres_counted = df1_genres.sort_values(ascending = False)

# %%
sorted_genres_counted_list = list(sorted_genres_counted.head(10))
len(sorted_genres_counted_list)
# Out:
# 10

# %%
genres_names = list(df1_genres.sort_values(ascending = False).index)
len(genres_names)
# Out:
# 1085

# %%
genres_names[7]
# Out:
# 'Biography,Documentary'

# %%
genres_names
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy,Drama',
#  'Thriller',
#  'Action',
#  'Biography,Documentary',
#  'Drama,Romance',
#  'Comedy,Drama,Romance',
#  'Documentary,Drama',
#  'Comedy,Romance',
#  'Romance',
#  'Documentary,Music',
#  'Drama,Thriller',
#  'Documentary,History',
#  'Horror,Thriller',
#  'Biography,Documentary,History',
#  'Biography,Documentary,Drama',
#  'Family',
#  'Animation',
#  'Drama,Family',
#  'Action,Crime,Drama',
#  'Comedy,Horror',
#  'Crime,Drama',
#  'Crime',
#  'Sci-Fi',
#  'Music',
#  'Documentary,Sport',
#  'Crime,Drama,Thriller',
#  'Documentary,News',
#  'Action,Drama',
#  'Biography,Documentary,Music',
#  'Mystery',
#  'Biography',
#  'Biography,Documentary,Family',
#  'Documentary,Family',
#  'Horror,Mystery,Thriller',
#  'Adventure',
#  'Fantasy',
#  'Action,Comedy',
#  'Drama,Horror,Thriller',
#  'Adventure,Documentary',
#  'Drama,Mystery,Thriller',
#  'Action,Thriller',
#  'History',
#  'Comedy,Drama,Family',
# ...

# %%
#genre_count = {}

#for genre in genres_names:
#   if record['species'] in genres_names:
#        genre_count[record['species']] += 1
#    else:
#        species_count3[record['species']] += 1

# %%
genres_names[:10]
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy,Drama',
#  'Thriller',
#  'Action',
#  'Biography,Documentary',
#  'Drama,Romance',
#  'Comedy,Drama,Romance']

# %%
sorted_genres_counted_list
# Out:
# [32185, 21486, 9177, 4372, 3519, 3046, 2219, 2115, 2079, 1558]

# %%
bar_chart_title = 'Genres by Popularity' 
bar_chart_count_label = 'Number of Movies'
bar_chart_series_label = 'Genres'


player_count_figure1, ax1 = plt.subplots(figsize=(10, 6))

ax1.bar(x = testList, height = sorted_genres_counted_list ) 

ax1.set_title(bar_chart_title) 
ax1.set_xlabel(bar_chart_series_label, fontsize=20) 
ax1.set_ylabel(bar_chart_count_label)
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
#Here I have the genres counted

sorted_genres_counted
# Out:
# genres
# Documentary                      32185
# Drama                            21486
# Comedy                            9177
# Horror                            4372
# Comedy,Drama                      3519
#                                  ...
# Documentary,Horror,Romance           1
# Documentary,Horror,Reality-TV        1
# Animation,Biography,Fantasy          1
# Documentary,Horror,News              1
# History,Reality-TV,War               1
# Name: movie_id, Length: 1085, dtype: int64

# %%
test_string = df1_genres.sort_values(ascending = False).index
test_string
# Out:
# Index(['Documentary', 'Drama', 'Comedy', 'Horror', 'Comedy,Drama', 'Thriller',
#        'Action', 'Biography,Documentary', 'Drama,Romance',
#        'Comedy,Drama,Romance',
#        ...
#        'Adventure,Romance,Sport', 'Adventure,Romance,Thriller',
#        'Documentary,Music,Reality-TV', 'Mystery,Thriller,Western',
#        'Documentary,Horror,Sci-Fi', 'Documentary,Horror,Romance',
#        'Documentary,Horror,Reality-TV', 'Animation,Biography,Fantasy',
#        'Documentary,Horror,News', 'History,Reality-TV,War'],
#       dtype='object', name='genres', length=1085)

# %%
test_string[7]
# Out:
# 'Biography,Documentary'

# %%
test_string[7].split(",")
# Out:
# ['Biography', 'Documentary']

# %%
len(test_string[7].split(","))
# Out:
# 2

# %%
#test_list = test_string[0].split(",")
#test_list

# %%
test_string_list = list(test_string)
test_string_list
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Comedy,Drama',
#  'Thriller',
#  'Action',
#  'Biography,Documentary',
#  'Drama,Romance',
#  'Comedy,Drama,Romance',
#  'Documentary,Drama',
#  'Comedy,Romance',
#  'Romance',
#  'Documentary,Music',
#  'Drama,Thriller',
#  'Documentary,History',
#  'Horror,Thriller',
#  'Biography,Documentary,History',
#  'Biography,Documentary,Drama',
#  'Family',
#  'Animation',
#  'Drama,Family',
#  'Action,Crime,Drama',
#  'Comedy,Horror',
#  'Crime,Drama',
#  'Crime',
#  'Sci-Fi',
#  'Music',
#  'Documentary,Sport',
#  'Crime,Drama,Thriller',
#  'Documentary,News',
#  'Action,Drama',
#  'Biography,Documentary,Music',
#  'Mystery',
#  'Biography',
#  'Biography,Documentary,Family',
#  'Documentary,Family',
#  'Horror,Mystery,Thriller',
#  'Adventure',
#  'Fantasy',
#  'Action,Comedy',
#  'Drama,Horror,Thriller',
#  'Adventure,Documentary',
#  'Drama,Mystery,Thriller',
#  'Action,Thriller',
#  'History',
#  'Comedy,Drama,Family',
# ...

# %%
len(test_string[4].split(","))
# Out:
# 2

# %%
 ##len(test_string[individual_genre].split(","))

# %%
##len(test_string[4].split(","))

# %%
unique_genre_names = []

for i in test_string_list:
    new_num = len(i.split(","))
    if new_num == 1 :
        unique_genre_names.append(i)
    else:
        None
        
    
 #   if len(test_string[individual_genre].split(",")) == 1:
  #      unique_genre_names.append(test_string[individual_genre].split(","))

# %%
unique_genre_names
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Romance',
#  'Family',
#  'Animation',
#  'Crime',
#  'Sci-Fi',
#  'Music',
#  'Mystery',
#  'Biography',
#  'Adventure',
#  'Fantasy',
#  'History',
#  'Musical',
#  'Sport',
#  'Western',
#  'War',
#  'Reality-TV',
#  'Talk-Show',
#  'News',
#  'Game-Show']

# %%
genre_list = list(df1['genres'].dropna())

# %%
genre_list
# Out:
# ['Action,Crime,Drama',
#  'Biography,Drama',
#  'Drama',
#  'Comedy,Drama',
#  'Comedy,Drama,Fantasy',
#  'Comedy',
#  'Horror,Thriller',
#  'Adventure,Animation,Comedy',
#  'Documentary,History',
#  'Biography',
#  'Drama',
#  'History',
#  'Documentary',
#  'Drama',
#  'Documentary',
#  'Animation,Drama,History',
#  'Drama',
#  'Drama',
#  'Drama,Mystery',
#  'Action,Animation,Comedy',
#  'Crime,Drama',
#  'Biography,Comedy,Drama',
#  'Documentary',
#  'Documentary',
#  'Drama',
#  'Action,Drama',
#  'Documentary,History',
#  'Sci-Fi',
#  'Comedy',
#  'Documentary',
#  'Thriller',
#  'Action,Adventure,Fantasy',
#  'Crime,Drama',
#  'Drama,Romance',
#  'Adventure,Animation,Sci-Fi',
#  'Action,Crime,Drama',
#  'Drama,Horror',
#  'Drama,Mystery,Thriller',
#  'Drama,Family',
#  'Adventure,Comedy,Romance',
#  'Comedy,Drama',
#  'Adventure,Animation,Comedy',
#  'Adventure,Drama,Romance',
#  'Comedy,Crime,Drama',
#  'Biography',
#  'Horror',
#  'Comedy,Drama',
#  'Drama',
# ...

# %%
unique_genre_names
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Romance',
#  'Family',
#  'Animation',
#  'Crime',
#  'Sci-Fi',
#  'Music',
#  'Mystery',
#  'Biography',
#  'Adventure',
#  'Fantasy',
#  'History',
#  'Musical',
#  'Sport',
#  'Western',
#  'War',
#  'Reality-TV',
#  'Talk-Show',
#  'News',
#  'Game-Show']

# %%
unique_genre_names_dic={}
for word in unique_genre_names: # think word = 'Documentary'
    unique_genre_names_dic.update({word : 0})   
unique_genre_names_dic
# Out:
# {'Documentary': 0,
#  'Drama': 0,
#  'Comedy': 0,
#  'Horror': 0,
#  'Thriller': 0,
#  'Action': 0,
#  'Romance': 0,
#  'Family': 0,
#  'Animation': 0,
#  'Crime': 0,
#  'Sci-Fi': 0,
#  'Music': 0,
#  'Mystery': 0,
#  'Biography': 0,
#  'Adventure': 0,
#  'Fantasy': 0,
#  'History': 0,
#  'Musical': 0,
#  'Sport': 0,
#  'Western': 0,
#  'War': 0,
#  'Reality-TV': 0,
#  'Talk-Show': 0,
#  'News': 0,
#  'Game-Show': 0}

# %%
for string_name in genre_list:
    string_list = string_name.split(',')
    for word in string_list: # think word = 'Action', then word = 'Crime', then word='Drama'
        if word in unique_genre_names:  #if word is in the unique names dictionary, add 1 to the dictionary
            unique_genre_names_dic[word] = unique_genre_names_dic[word]+1

# %%
#Here I sorted the dictionary of genres by the number of movies (values)
sorted_genre_dict = dict(sorted(unique_genre_names_dic.items(),key=lambda x:x[1],reverse = True))
sorted_genre_dict
# Out:
# {'Documentary': 51640,
#  'Drama': 49883,
#  'Comedy': 25312,
#  'Thriller': 11883,
#  'Horror': 10805,
#  'Action': 10335,
#  'Romance': 9372,
#  'Biography': 8722,
#  'Crime': 6753,
#  'Adventure': 6465,
#  'Family': 6227,
#  'History': 6225,
#  'Mystery': 4659,
#  'Music': 4314,
#  'Fantasy': 3516,
#  'Sci-Fi': 3365,
#  'Animation': 2799,
#  'Sport': 2234,
#  'News': 1551,
#  'Musical': 1430,
#  'War': 1405,
#  'Western': 467,
#  'Reality-TV': 98,
#  'Talk-Show': 50,
#  'Game-Show': 4}

# %%
unique_genre_names_dic
# Out:
# {'Documentary': 51640,
#  'Drama': 49883,
#  'Comedy': 25312,
#  'Horror': 10805,
#  'Thriller': 11883,
#  'Action': 10335,
#  'Romance': 9372,
#  'Family': 6227,
#  'Animation': 2799,
#  'Crime': 6753,
#  'Sci-Fi': 3365,
#  'Music': 4314,
#  'Mystery': 4659,
#  'Biography': 8722,
#  'Adventure': 6465,
#  'Fantasy': 3516,
#  'History': 6225,
#  'Musical': 1430,
#  'Sport': 2234,
#  'Western': 467,
#  'War': 1405,
#  'Reality-TV': 98,
#  'Talk-Show': 50,
#  'News': 1551,
#  'Game-Show': 4}

# %%
word = 'Adult'
if word in unique_genre_names:
    unique_genre_names_dic[word] = unique_genre_names_dic[word]+1

# %%
unique_genre_names
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Romance',
#  'Family',
#  'Animation',
#  'Crime',
#  'Sci-Fi',
#  'Music',
#  'Mystery',
#  'Biography',
#  'Adventure',
#  'Fantasy',
#  'History',
#  'Musical',
#  'Sport',
#  'Western',
#  'War',
#  'Reality-TV',
#  'Talk-Show',
#  'News',
#  'Game-Show']

# %%
unique_genre_names
# Out:
# ['Documentary',
#  'Drama',
#  'Comedy',
#  'Horror',
#  'Thriller',
#  'Action',
#  'Romance',
#  'Family',
#  'Animation',
#  'Crime',
#  'Sci-Fi',
#  'Music',
#  'Mystery',
#  'Biography',
#  'Adventure',
#  'Fantasy',
#  'History',
#  'Musical',
#  'Sport',
#  'Western',
#  'War',
#  'Reality-TV',
#  'Talk-Show',
#  'News',
#  'Game-Show']

# %%
genre_list[0].split(',')
# Out:
# ['Action', 'Crime', 'Drama']

# %%
unique_genre_names_dic['Action'] = unique_genre_names_dic['Action']+1
