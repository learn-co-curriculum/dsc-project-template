# %% [markdown]
# ![example](images/director_shot.jpeg)

# %% [markdown]
# # Module 1 Project
# ## What movies should Microsoft make?
#
# **Authors:**<br>
#
# ***
# Student 1
#
# Student 2
#
# Student 3
# ***

# %% [markdown]
# ## Recommendations
#
# Based on our anaylsis and findings, we advise Microsoft to:
#
# ***
# Example: genre choice, season, ROI, percent ROI, actor type, studio type...
# ***

# %% [markdown]
# ## Overview
#
# A one-paragraph overview of the project, including the business problem and related data analysis questions.
# ***
# * "How did you pick the data analysis question(s) that you did?"
# * "Why are these questions important from a business perspective?"
# ***

# %% [markdown]
# ## Data Understanding
#
# Describe the data being used for this project.
# ***
# * "Where did the data come from, and how do they relate to the data analysis questions?"
# * "What do the data represent? Who is in the sample and what variables are included?"
# * "What is the target variable?"
# * "What are the properties of the variables you intend to use?"
# ***

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Import the visualization package you created

import code.visualizations as viz

# %%
# These sample functions take no arguments currently, but you pass full_dataset to them for your project

viz.sample_plot_1()

# %%
viz.sample_plot2()

# %% [markdown]
# ## Data Preparation
#
# Describe and justify the process for preparing the data for analysis.
#
# ***
# * Were there variables you dropped or created?
# * How did you address missing values?
# * Why did you perform the operations described?
# ***

# %% [markdown]
# For details of our cleaning code, please look at the scripts in the `code` folder.

# %%
# here you run your code to clean the data
import code.data_cleaning as dc

full_dataset = dc.full_clean()

# %% [markdown]
# ## Data Modeling
#
# ***
# * "How did you analyze or model the data?"
# * "Why did you pick that modeling approach?"
# * "How does that modeling approach align with the data analysis questions?"
# ***

# %%
# here you run your code to model the data

# %% [markdown]
# ## Evaluation
#
# ***
# Here is where you would answer the following questions:
#
# Answer:
# * "How would you interpret the results?"
# ***

# %% [markdown]
# ## Conclusions
#
# Based on the results, here are the recommendations for the business problem

# %% [markdown]
# ## Limitations
#
# ***
# Here is where you  would wrtie your response to:
#
# * "How confident are you in the quality of the results?"
# * "What are some of the things that could cause the results to be wrong or not represetative?"
#     - large variance?
#     - need more granularity?
#     - be specific in your reasoning
# ***

# %% [markdown]
# ## Next Steps
#
#
# ***
#
# Here is where you  would write your response to:
#
# - If you could ask for more information, what would you want?
# - What variable would you explore next?
# - Does one of your current variables need a deeper dive?
# ***

# %% [markdown]
# ## Thank you!
