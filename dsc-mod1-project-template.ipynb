# %% [markdown]
# ![movies](images_and_code/director_shot.jpeg)

# %% [markdown]
# # Module 1 Project
# ## What movies should Microsoft make?
#
# **Authors:**<br>
#
# ***
# Student 1
#
# Student 2
#
# Student 3
# ***

# %% [markdown]
# ## Business Problem
#
# Microsoft* sees all the big companies creating original video content, and they want to get in on the fun. They have decided to create a new movie studio, but the problem is they don’t know anything about creating movies.
#
# Our team analyzied movie data from  [Box Office Mojo](www.boxofficemojo.com), [IMDB](www.IMDB.com), [Rotten Tomatoes](www.rottentomatoes.com), and [TheMovieDB.org](www.TheMovieDB.org) to help them better understand the movie industry.

# %% [markdown]
# ## Recommendations
#
# Based on our anaylsis and findings, we advise Microsoft to:
#
# ####### THREE RECOMENDATIONS HERE#####
#
# Example: genre choice, season, ROI, percent ROI, actor type, studio type...
#
# #######################################

# %% [markdown]
# ## Analysis and Approach

# %% [markdown]
# ######################################
# ####### FILL IN AND ANSWER HERE#####
#
# * "How did you pick the question(s) that you did?"
# * "Why are these questions important from a business perspective?"
# * "Why did you pick those features?"
#
# ######################################

# %%
# Import standard packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# Packages we created
import images_and_code.visualizations as viz
import data_cleaning_code.data_cleaning as dc

# %% [markdown]
# ### Cleaning
#
# ##################<br>
# Choices made:
# - How did you address missing values?
# - Were there new variables you creates?
# - How did you decide on the data cleaning options you performed?
# - Did any variables seem unreliable?
#
# ##################
#
# (for details of our specific cleaning code, please look at your scripts in the [data_cleaning_code] folder)

# %%
full_dataset = dc.full_clean()

# %% [markdown]
# #### Analysis

# %% [markdown]
# #### Findings & Application
#
# ##################
#
# * "Why did you select those visualizations and what did you learn from each of them?"
# * "How would you interpret the results?"
#
# ##################

# %%
# These sample functions take no arguments currently, but you pass full_dataset to them for your project
viz.sample_plot_1()

# %%
# These sample functions take no arguments currently, but you pass full_dataset to them for your project
viz.sample_plot2()

# %% [markdown]
# ## Limitations of our Analysis
# ### Taking our work with a grain of salt
#
# ###################################<br>
# * "How confident are you in the quality of the results?"
# * "What are some of the things that could cause the results to be wrong or not represetative?"
#     - large variance?
#     - need more granularity?
#     - be specific in your reasoning
#
# ###################################

# %% [markdown]
# #### Next Steps
#
#
# #############################
# - If you could ask for more information, what would you want?
# - What variable would you explore next?
# - Does one of your current variables need a deeper dive?
#
# #############################

# %% [markdown]
# ## Thank you!
